# %% [markdown]
# # External Lab

# %% [markdown]
# # Part-1

# %% [markdown]
# ## About the dataset
#
# This is perhaps the best known database to be found in the pattern recognition literature. The data set contains 3 classes of 50 instances each, where each class refers to a type of iris plant.  One class is linearly separable from the other 2; the latter are NOT linearly separable from each other.
#
# Attribute Information:
#    1. sepal length in cm
#    2. sepal width in cm
#    3. petal length in cm
#    4. petal width in cm
#    5. class:
#       -- Iris Setosa
#       -- Iris Versicolour
#       -- Iris Virginica

# %%
import numpy as np
import pandas as pd

# %%
from google.colab import drive
drive.mount('/content/drive')
# Out:
# Drive already mounted at /content/drive; to attempt to forcibly remount, call drive.mount("/content/drive", force_remount=True).

# %% [markdown]
# ### Read the dataset and store it in the dataframe named Iris

# %%
iris=pd.read_csv('/content/drive/My Drive/Colab Notebooks/lab1606/Iris.csv')
iris.head()
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)  ...  Petal width (in cm)        Class
# 0                   5.1                  3.5  ...                  0.2  Iris-setosa
# 1                   4.9                  3.0  ...                  0.2  Iris-setosa
# 2                   4.7                  3.2  ...                  0.2  Iris-setosa
# 3                   4.6                  3.1  ...                  0.2  Iris-setosa
# 4                   5.0                  3.6  ...                  0.2  Iris-setosa
#
# [5 rows x 5 columns]

# %% [markdown]
# ### Find out the datatypes of each and every column

# %%
iris.dtypes
# Out:
# Sepal Length (in cm)    float64
# Sepal Width in (cm)     float64
# Petal length (in cm)    float64
# Petal width (in cm)     float64
# Class                    object
# dtype: object

# %% [markdown]
# ### Print top 10 & bottom 10 samples from the dataframe

# %%
df = iris.iloc[np.r_[0:10, -10:0]]
print (df)
# Out:
#      Sepal Length (in cm)  ...           Class
# 0                     5.1  ...     Iris-setosa
# 1                     4.9  ...     Iris-setosa
# 2                     4.7  ...     Iris-setosa
# 3                     4.6  ...     Iris-setosa
# 4                     5.0  ...     Iris-setosa
# 5                     5.4  ...     Iris-setosa
# 6                     4.6  ...     Iris-setosa
# 7                     5.0  ...     Iris-setosa
# 8                     4.4  ...     Iris-setosa
# 9                     4.9  ...     Iris-setosa
# 140                   6.7  ...  Iris-virginica
# 141                   6.9  ...  Iris-virginica
# 142                   5.8  ...  Iris-virginica
# 143                   6.8  ...  Iris-virginica
# 144                   6.7  ...  Iris-virginica
# 145                   6.7  ...  Iris-virginica
# 146                   6.3  ...  Iris-virginica
# 147                   6.5  ...  Iris-virginica
# 148                   6.2  ...  Iris-virginica
# 149                   5.9  ...  Iris-virginica
#
# [20 rows x 5 columns]

# %% [markdown]
# ### Find the shape of the dataset

# %%
iris.shape
# Out:
# (150, 5)

# %% [markdown]
# ```
# # This is formatted as code
# ```
#
# ### Set the index of the dataframe to be the first column

# %%
iris.reset_index(level=0, inplace=True)
iris
# Out:
#      index  Sepal Length (in cm)  ...  Petal width (in cm)           Class
# 0        0                   5.1  ...                  0.2     Iris-setosa
# 1        1                   4.9  ...                  0.2     Iris-setosa
# 2        2                   4.7  ...                  0.2     Iris-setosa
# 3        3                   4.6  ...                  0.2     Iris-setosa
# 4        4                   5.0  ...                  0.2     Iris-setosa
# 5        5                   5.4  ...                  0.4     Iris-setosa
# 6        6                   4.6  ...                  0.3     Iris-setosa
# 7        7                   5.0  ...                  0.2     Iris-setosa
# 8        8                   4.4  ...                  0.2     Iris-setosa
# 9        9                   4.9  ...                  0.1     Iris-setosa
# 10      10                   5.4  ...                  0.2     Iris-setosa
# 11      11                   4.8  ...                  0.2     Iris-setosa
# 12      12                   4.8  ...                  0.1     Iris-setosa
# 13      13                   4.3  ...                  0.1     Iris-setosa
# 14      14                   5.8  ...                  0.2     Iris-setosa
# 15      15                   5.7  ...                  0.4     Iris-setosa
# 16      16                   5.4  ...                  0.4     Iris-setosa
# 17      17                   5.1  ...                  0.3     Iris-setosa
# 18      18                   5.7  ...                  0.3     Iris-setosa
# 19      19                   5.1  ...                  0.3     Iris-setosa
# 20      20                   5.4  ...                  0.2     Iris-setosa
# 21      21                   5.1  ...                  0.4     Iris-setosa
# 22      22                   4.6  ...                  0.2     Iris-setosa
# 23      23                   5.1  ...                  0.5     Iris-setosa
# 24      24                   4.8  ...                  0.2     Iris-setosa
# 25      25                   5.0  ...                  0.2     Iris-setosa
# 26      26                   5.0  ...                  0.4     Iris-setosa
# 27      27                   5.2  ...                  0.2     Iris-setosa
# 28      28                   5.2  ...                  0.2     Iris-setosa
# 29      29                   4.7  ...                  0.2     Iris-setosa
# ..     ...                   ...  ...                  ...             ...
# 120    120                   6.9  ...                  2.3  Iris-virginica
# 121    121                   5.6  ...                  2.0  Iris-virginica
# 122    122                   7.7  ...                  2.0  Iris-virginica
# 123    123                   6.3  ...                  1.8  Iris-virginica
# 124    124                   6.7  ...                  2.1  Iris-virginica
# 125    125                   7.2  ...                  1.8  Iris-virginica
# 126    126                   6.2  ...                  1.8  Iris-virginica
# 127    127                   6.1  ...                  1.8  Iris-virginica
# 128    128                   6.4  ...                  2.1  Iris-virginica
# 129    129                   7.2  ...                  1.6  Iris-virginica
# 130    130                   7.4  ...                  1.9  Iris-virginica
# 131    131                   7.9  ...                  2.0  Iris-virginica
# 132    132                   6.4  ...                  2.2  Iris-virginica
# 133    133                   6.3  ...                  1.5  Iris-virginica
# 134    134                   6.1  ...                  1.4  Iris-virginica
# 135    135                   7.7  ...                  2.3  Iris-virginica
# 136    136                   6.3  ...                  2.4  Iris-virginica
# 137    137                   6.4  ...                  1.8  Iris-virginica
# 138    138                   6.0  ...                  1.8  Iris-virginica
# 139    139                   6.9  ...                  2.1  Iris-virginica
# 140    140                   6.7  ...                  2.4  Iris-virginica
# 141    141                   6.9  ...                  2.3  Iris-virginica
# 142    142                   5.8  ...                  1.9  Iris-virginica
# 143    143                   6.8  ...                  2.3  Iris-virginica
# 144    144                   6.7  ...                  2.5  Iris-virginica
# 145    145                   6.7  ...                  2.3  Iris-virginica
# 146    146                   6.3  ...                  1.9  Iris-virginica
# 147    147                   6.5  ...                  2.0  Iris-virginica
# 148    148                   6.2  ...                  2.3  Iris-virginica
# 149    149                   5.9  ...                  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %%
iris
# Out:
#      index  Sepal Length (in cm)  ...  Petal width (in cm)           Class
# 0        0                   5.1  ...                  0.2     Iris-setosa
# 1        1                   4.9  ...                  0.2     Iris-setosa
# 2        2                   4.7  ...                  0.2     Iris-setosa
# 3        3                   4.6  ...                  0.2     Iris-setosa
# 4        4                   5.0  ...                  0.2     Iris-setosa
# 5        5                   5.4  ...                  0.4     Iris-setosa
# 6        6                   4.6  ...                  0.3     Iris-setosa
# 7        7                   5.0  ...                  0.2     Iris-setosa
# 8        8                   4.4  ...                  0.2     Iris-setosa
# 9        9                   4.9  ...                  0.1     Iris-setosa
# 10      10                   5.4  ...                  0.2     Iris-setosa
# 11      11                   4.8  ...                  0.2     Iris-setosa
# 12      12                   4.8  ...                  0.1     Iris-setosa
# 13      13                   4.3  ...                  0.1     Iris-setosa
# 14      14                   5.8  ...                  0.2     Iris-setosa
# 15      15                   5.7  ...                  0.4     Iris-setosa
# 16      16                   5.4  ...                  0.4     Iris-setosa
# 17      17                   5.1  ...                  0.3     Iris-setosa
# 18      18                   5.7  ...                  0.3     Iris-setosa
# 19      19                   5.1  ...                  0.3     Iris-setosa
# 20      20                   5.4  ...                  0.2     Iris-setosa
# 21      21                   5.1  ...                  0.4     Iris-setosa
# 22      22                   4.6  ...                  0.2     Iris-setosa
# 23      23                   5.1  ...                  0.5     Iris-setosa
# 24      24                   4.8  ...                  0.2     Iris-setosa
# 25      25                   5.0  ...                  0.2     Iris-setosa
# 26      26                   5.0  ...                  0.4     Iris-setosa
# 27      27                   5.2  ...                  0.2     Iris-setosa
# 28      28                   5.2  ...                  0.2     Iris-setosa
# 29      29                   4.7  ...                  0.2     Iris-setosa
# ..     ...                   ...  ...                  ...             ...
# 120    120                   6.9  ...                  2.3  Iris-virginica
# 121    121                   5.6  ...                  2.0  Iris-virginica
# 122    122                   7.7  ...                  2.0  Iris-virginica
# 123    123                   6.3  ...                  1.8  Iris-virginica
# 124    124                   6.7  ...                  2.1  Iris-virginica
# 125    125                   7.2  ...                  1.8  Iris-virginica
# 126    126                   6.2  ...                  1.8  Iris-virginica
# 127    127                   6.1  ...                  1.8  Iris-virginica
# 128    128                   6.4  ...                  2.1  Iris-virginica
# 129    129                   7.2  ...                  1.6  Iris-virginica
# 130    130                   7.4  ...                  1.9  Iris-virginica
# 131    131                   7.9  ...                  2.0  Iris-virginica
# 132    132                   6.4  ...                  2.2  Iris-virginica
# 133    133                   6.3  ...                  1.5  Iris-virginica
# 134    134                   6.1  ...                  1.4  Iris-virginica
# 135    135                   7.7  ...                  2.3  Iris-virginica
# 136    136                   6.3  ...                  2.4  Iris-virginica
# 137    137                   6.4  ...                  1.8  Iris-virginica
# 138    138                   6.0  ...                  1.8  Iris-virginica
# 139    139                   6.9  ...                  2.1  Iris-virginica
# 140    140                   6.7  ...                  2.4  Iris-virginica
# 141    141                   6.9  ...                  2.3  Iris-virginica
# 142    142                   5.8  ...                  1.9  Iris-virginica
# 143    143                   6.8  ...                  2.3  Iris-virginica
# 144    144                   6.7  ...                  2.5  Iris-virginica
# 145    145                   6.7  ...                  2.3  Iris-virginica
# 146    146                   6.3  ...                  1.9  Iris-virginica
# 147    147                   6.5  ...                  2.0  Iris-virginica
# 148    148                   6.2  ...                  2.3  Iris-virginica
# 149    149                   5.9  ...                  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Use iloc function to print all the rows of the 3rd column

# %%
iris.iloc[:,2]
# Out:
# 0      3.5
# 1      3.0
# 2      3.2
# 3      3.1
# 4      3.6
# 5      3.9
# 6      3.4
# 7      3.4
# 8      2.9
# 9      3.1
# 10     3.7
# 11     3.4
# 12     3.0
# 13     3.0
# 14     4.0
# 15     4.4
# 16     3.9
# 17     3.5
# 18     3.8
# 19     3.8
# 20     3.4
# 21     3.7
# 22     3.6
# 23     3.3
# 24     3.4
# 25     3.0
# 26     3.4
# 27     3.5
# 28     3.4
# 29     3.2
#       ...
# 120    3.2
# 121    2.8
# 122    2.8
# 123    2.7
# 124    3.3
# 125    3.2
# 126    2.8
# 127    3.0
# 128    2.8
# 129    3.0
# 130    2.8
# 131    3.8
# 132    2.8
# 133    2.8
# 134    2.6
# 135    3.0
# 136    3.4
# 137    3.1
# 138    3.0
# 139    3.1
# 140    3.1
# 141    3.1
# 142    2.7
# 143    3.2
# 144    3.3
# 145    3.0
# 146    2.5
# 147    3.0
# 148    3.4
# 149    3.0
# Name: Sepal Width in (cm), Length: 150, dtype: float64

# %% [markdown]
# ### Slicing
# Print only the Sepal width and Sepal Length for first 10 rows

# %%
iris.iloc[:10,1:3]
# Out:
#    Sepal Length (in cm)  Sepal Width in (cm)
# 0                   5.1                  3.5
# 1                   4.9                  3.0
# 2                   4.7                  3.2
# 3                   4.6                  3.1
# 4                   5.0                  3.6
# 5                   5.4                  3.9
# 6                   4.6                  3.4
# 7                   5.0                  3.4
# 8                   4.4                  2.9
# 9                   4.9                  3.1

# %% [markdown]
# ### Using Logical statements for indexing
# Print all the columns of row which has class name "Iris-setosa"

# %%
iris.loc[iris['Class'] == 'Iris-setosa']
# Out:
#     index  Sepal Length (in cm)  ...  Petal width (in cm)        Class
# 0       0                   5.1  ...                  0.2  Iris-setosa
# 1       1                   4.9  ...                  0.2  Iris-setosa
# 2       2                   4.7  ...                  0.2  Iris-setosa
# 3       3                   4.6  ...                  0.2  Iris-setosa
# 4       4                   5.0  ...                  0.2  Iris-setosa
# 5       5                   5.4  ...                  0.4  Iris-setosa
# 6       6                   4.6  ...                  0.3  Iris-setosa
# 7       7                   5.0  ...                  0.2  Iris-setosa
# 8       8                   4.4  ...                  0.2  Iris-setosa
# 9       9                   4.9  ...                  0.1  Iris-setosa
# 10     10                   5.4  ...                  0.2  Iris-setosa
# 11     11                   4.8  ...                  0.2  Iris-setosa
# 12     12                   4.8  ...                  0.1  Iris-setosa
# 13     13                   4.3  ...                  0.1  Iris-setosa
# 14     14                   5.8  ...                  0.2  Iris-setosa
# 15     15                   5.7  ...                  0.4  Iris-setosa
# 16     16                   5.4  ...                  0.4  Iris-setosa
# 17     17                   5.1  ...                  0.3  Iris-setosa
# 18     18                   5.7  ...                  0.3  Iris-setosa
# 19     19                   5.1  ...                  0.3  Iris-setosa
# 20     20                   5.4  ...                  0.2  Iris-setosa
# 21     21                   5.1  ...                  0.4  Iris-setosa
# 22     22                   4.6  ...                  0.2  Iris-setosa
# 23     23                   5.1  ...                  0.5  Iris-setosa
# 24     24                   4.8  ...                  0.2  Iris-setosa
# 25     25                   5.0  ...                  0.2  Iris-setosa
# 26     26                   5.0  ...                  0.4  Iris-setosa
# 27     27                   5.2  ...                  0.2  Iris-setosa
# 28     28                   5.2  ...                  0.2  Iris-setosa
# 29     29                   4.7  ...                  0.2  Iris-setosa
# 30     30                   4.8  ...                  0.2  Iris-setosa
# 31     31                   5.4  ...                  0.4  Iris-setosa
# 32     32                   5.2  ...                  0.1  Iris-setosa
# 33     33                   5.5  ...                  0.2  Iris-setosa
# 34     34                   4.9  ...                  0.1  Iris-setosa
# 35     35                   5.0  ...                  0.2  Iris-setosa
# 36     36                   5.5  ...                  0.2  Iris-setosa
# 37     37                   4.9  ...                  0.1  Iris-setosa
# 38     38                   4.4  ...                  0.2  Iris-setosa
# 39     39                   5.1  ...                  0.2  Iris-setosa
# 40     40                   5.0  ...                  0.3  Iris-setosa
# 41     41                   4.5  ...                  0.3  Iris-setosa
# 42     42                   4.4  ...                  0.2  Iris-setosa
# 43     43                   5.0  ...                  0.6  Iris-setosa
# 44     44                   5.1  ...                  0.4  Iris-setosa
# 45     45                   4.8  ...                  0.3  Iris-setosa
# 46     46                   5.1  ...                  0.2  Iris-setosa
# 47     47                   4.6  ...                  0.2  Iris-setosa
# 48     48                   5.3  ...                  0.2  Iris-setosa
# 49     49                   5.0  ...                  0.2  Iris-setosa
#
# [50 rows x 6 columns]

# %% [markdown]
# ### Multiply Sepal Length and width and store it under the column name "SepalExtra" in the same Iris dataframe

# %%
iris['SepalExtra'] = iris['Sepal Length (in cm)']*iris['Sepal Width in (cm)']

# %%
iris
# Out:
#      index  Sepal Length (in cm)  ...           Class  SepalExtra
# 0        0                   5.1  ...     Iris-setosa       17.85
# 1        1                   4.9  ...     Iris-setosa       14.70
# 2        2                   4.7  ...     Iris-setosa       15.04
# 3        3                   4.6  ...     Iris-setosa       14.26
# 4        4                   5.0  ...     Iris-setosa       18.00
# 5        5                   5.4  ...     Iris-setosa       21.06
# 6        6                   4.6  ...     Iris-setosa       15.64
# 7        7                   5.0  ...     Iris-setosa       17.00
# 8        8                   4.4  ...     Iris-setosa       12.76
# 9        9                   4.9  ...     Iris-setosa       15.19
# 10      10                   5.4  ...     Iris-setosa       19.98
# 11      11                   4.8  ...     Iris-setosa       16.32
# 12      12                   4.8  ...     Iris-setosa       14.40
# 13      13                   4.3  ...     Iris-setosa       12.90
# 14      14                   5.8  ...     Iris-setosa       23.20
# 15      15                   5.7  ...     Iris-setosa       25.08
# 16      16                   5.4  ...     Iris-setosa       21.06
# 17      17                   5.1  ...     Iris-setosa       17.85
# 18      18                   5.7  ...     Iris-setosa       21.66
# 19      19                   5.1  ...     Iris-setosa       19.38
# 20      20                   5.4  ...     Iris-setosa       18.36
# 21      21                   5.1  ...     Iris-setosa       18.87
# 22      22                   4.6  ...     Iris-setosa       16.56
# 23      23                   5.1  ...     Iris-setosa       16.83
# 24      24                   4.8  ...     Iris-setosa       16.32
# 25      25                   5.0  ...     Iris-setosa       15.00
# 26      26                   5.0  ...     Iris-setosa       17.00
# 27      27                   5.2  ...     Iris-setosa       18.20
# 28      28                   5.2  ...     Iris-setosa       17.68
# 29      29                   4.7  ...     Iris-setosa       15.04
# ..     ...                   ...  ...             ...         ...
# 120    120                   6.9  ...  Iris-virginica       22.08
# 121    121                   5.6  ...  Iris-virginica       15.68
# 122    122                   7.7  ...  Iris-virginica       21.56
# 123    123                   6.3  ...  Iris-virginica       17.01
# 124    124                   6.7  ...  Iris-virginica       22.11
# 125    125                   7.2  ...  Iris-virginica       23.04
# 126    126                   6.2  ...  Iris-virginica       17.36
# 127    127                   6.1  ...  Iris-virginica       18.30
# 128    128                   6.4  ...  Iris-virginica       17.92
# 129    129                   7.2  ...  Iris-virginica       21.60
# 130    130                   7.4  ...  Iris-virginica       20.72
# 131    131                   7.9  ...  Iris-virginica       30.02
# 132    132                   6.4  ...  Iris-virginica       17.92
# 133    133                   6.3  ...  Iris-virginica       17.64
# 134    134                   6.1  ...  Iris-virginica       15.86
# 135    135                   7.7  ...  Iris-virginica       23.10
# 136    136                   6.3  ...  Iris-virginica       21.42
# 137    137                   6.4  ...  Iris-virginica       19.84
# 138    138                   6.0  ...  Iris-virginica       18.00
# 139    139                   6.9  ...  Iris-virginica       21.39
# 140    140                   6.7  ...  Iris-virginica       20.77
# 141    141                   6.9  ...  Iris-virginica       21.39
# 142    142                   5.8  ...  Iris-virginica       15.66
# 143    143                   6.8  ...  Iris-virginica       21.76
# 144    144                   6.7  ...  Iris-virginica       22.11
# 145    145                   6.7  ...  Iris-virginica       20.10
# 146    146                   6.3  ...  Iris-virginica       15.75
# 147    147                   6.5  ...  Iris-virginica       19.50
# 148    148                   6.2  ...  Iris-virginica       21.08
# 149    149                   5.9  ...  Iris-virginica       17.70
#
# [150 rows x 7 columns]

# %% [markdown]
# ### Find out the mean and variance for each column but for class column

# %%
iris.mean(axis = 0, skipna = True)
# Out:
# index                   74.500000
# Sepal Length (in cm)     5.843333
# Sepal Width in (cm)      3.054000
# Petal length (in cm)     3.758667
# Petal width (in cm)      1.198667
# SepalExtra              17.806533
# dtype: float64

# %% [markdown]
# ### Write a function that accepts two numbers as input and prints them - Pass the Sepal length and sepal width of 5th row and print the output

# %%
def func (x,y):
  return x,y
func(iris.iloc[5,0],iris.iloc[5,1])
# Out:
# (5, 5.4)

# %% [markdown]
# ### Find the range of all the columns in the dataset
#
# *Range = Max value - Min value (in the column)*

# %%
b=iris.drop('Class',1)
for a in b.columns:
  range=max(b[a]-min(b[a]))
range
# Out:
# 20.02

# %% [markdown]
# ### Sort the entire dataset according to the column Petal width

# %%
iris1=iris.sort_values(iris.columns[4])
iris1
# Out:
#      index  Sepal Length (in cm)  ...           Class  SepalExtra
# 32      32                   5.2  ...     Iris-setosa       21.32
# 13      13                   4.3  ...     Iris-setosa       12.90
# 37      37                   4.9  ...     Iris-setosa       15.19
# 9        9                   4.9  ...     Iris-setosa       15.19
# 12      12                   4.8  ...     Iris-setosa       14.40
# 34      34                   4.9  ...     Iris-setosa       15.19
# 0        0                   5.1  ...     Iris-setosa       17.85
# 27      27                   5.2  ...     Iris-setosa       18.20
# 28      28                   5.2  ...     Iris-setosa       17.68
# 29      29                   4.7  ...     Iris-setosa       15.04
# 30      30                   4.8  ...     Iris-setosa       14.88
# 33      33                   5.5  ...     Iris-setosa       23.10
# 36      36                   5.5  ...     Iris-setosa       19.25
# 38      38                   4.4  ...     Iris-setosa       13.20
# 39      39                   5.1  ...     Iris-setosa       17.34
# 42      42                   4.4  ...     Iris-setosa       14.08
# 46      46                   5.1  ...     Iris-setosa       19.38
# 47      47                   4.6  ...     Iris-setosa       14.72
# 48      48                   5.3  ...     Iris-setosa       19.61
# 49      49                   5.0  ...     Iris-setosa       16.50
# 25      25                   5.0  ...     Iris-setosa       15.00
# 24      24                   4.8  ...     Iris-setosa       16.32
# 35      35                   5.0  ...     Iris-setosa       16.00
# 3        3                   4.6  ...     Iris-setosa       14.26
# 2        2                   4.7  ...     Iris-setosa       15.04
# 7        7                   5.0  ...     Iris-setosa       17.00
# 8        8                   4.4  ...     Iris-setosa       12.76
# 10      10                   5.4  ...     Iris-setosa       19.98
# 4        4                   5.0  ...     Iris-setosa       18.00
# 11      11                   4.8  ...     Iris-setosa       16.32
# ..     ...                   ...  ...             ...         ...
# 111    111                   6.4  ...  Iris-virginica       17.28
# 121    121                   5.6  ...  Iris-virginica       15.68
# 122    122                   7.7  ...  Iris-virginica       21.56
# 147    147                   6.5  ...  Iris-virginica       19.50
# 113    113                   5.7  ...  Iris-virginica       14.25
# 131    131                   7.9  ...  Iris-virginica       30.02
# 110    110                   6.5  ...  Iris-virginica       20.80
# 139    139                   6.9  ...  Iris-virginica       21.39
# 102    102                   7.1  ...  Iris-virginica       21.30
# 112    112                   6.8  ...  Iris-virginica       20.40
# 105    105                   7.6  ...  Iris-virginica       22.80
# 124    124                   6.7  ...  Iris-virginica       22.11
# 128    128                   6.4  ...  Iris-virginica       17.92
# 117    117                   7.7  ...  Iris-virginica       29.26
# 132    132                   6.4  ...  Iris-virginica       17.92
# 104    104                   6.5  ...  Iris-virginica       19.50
# 120    120                   6.9  ...  Iris-virginica       22.08
# 115    115                   6.4  ...  Iris-virginica       20.48
# 148    148                   6.2  ...  Iris-virginica       21.08
# 141    141                   6.9  ...  Iris-virginica       21.39
# 143    143                   6.8  ...  Iris-virginica       21.76
# 145    145                   6.7  ...  Iris-virginica       20.10
# 118    118                   7.7  ...  Iris-virginica       20.02
# 135    135                   7.7  ...  Iris-virginica       23.10
# 136    136                   6.3  ...  Iris-virginica       21.42
# 140    140                   6.7  ...  Iris-virginica       20.77
# 114    114                   5.8  ...  Iris-virginica       16.24
# 100    100                   6.3  ...  Iris-virginica       20.79
# 144    144                   6.7  ...  Iris-virginica       22.11
# 109    109                   7.2  ...  Iris-virginica       25.92
#
# [150 rows x 7 columns]

# %% [markdown]
# ### Remove the new column "SepalExtra" from the dataframe

# %%
iris1=iris.drop(axis=0,columns='SepalExtra')
iris1
# Out:
#      index  Sepal Length (in cm)  ...  Petal width (in cm)           Class
# 0        0                   5.1  ...                  0.2     Iris-setosa
# 1        1                   4.9  ...                  0.2     Iris-setosa
# 2        2                   4.7  ...                  0.2     Iris-setosa
# 3        3                   4.6  ...                  0.2     Iris-setosa
# 4        4                   5.0  ...                  0.2     Iris-setosa
# 5        5                   5.4  ...                  0.4     Iris-setosa
# 6        6                   4.6  ...                  0.3     Iris-setosa
# 7        7                   5.0  ...                  0.2     Iris-setosa
# 8        8                   4.4  ...                  0.2     Iris-setosa
# 9        9                   4.9  ...                  0.1     Iris-setosa
# 10      10                   5.4  ...                  0.2     Iris-setosa
# 11      11                   4.8  ...                  0.2     Iris-setosa
# 12      12                   4.8  ...                  0.1     Iris-setosa
# 13      13                   4.3  ...                  0.1     Iris-setosa
# 14      14                   5.8  ...                  0.2     Iris-setosa
# 15      15                   5.7  ...                  0.4     Iris-setosa
# 16      16                   5.4  ...                  0.4     Iris-setosa
# 17      17                   5.1  ...                  0.3     Iris-setosa
# 18      18                   5.7  ...                  0.3     Iris-setosa
# 19      19                   5.1  ...                  0.3     Iris-setosa
# 20      20                   5.4  ...                  0.2     Iris-setosa
# 21      21                   5.1  ...                  0.4     Iris-setosa
# 22      22                   4.6  ...                  0.2     Iris-setosa
# 23      23                   5.1  ...                  0.5     Iris-setosa
# 24      24                   4.8  ...                  0.2     Iris-setosa
# 25      25                   5.0  ...                  0.2     Iris-setosa
# 26      26                   5.0  ...                  0.4     Iris-setosa
# 27      27                   5.2  ...                  0.2     Iris-setosa
# 28      28                   5.2  ...                  0.2     Iris-setosa
# 29      29                   4.7  ...                  0.2     Iris-setosa
# ..     ...                   ...  ...                  ...             ...
# 120    120                   6.9  ...                  2.3  Iris-virginica
# 121    121                   5.6  ...                  2.0  Iris-virginica
# 122    122                   7.7  ...                  2.0  Iris-virginica
# 123    123                   6.3  ...                  1.8  Iris-virginica
# 124    124                   6.7  ...                  2.1  Iris-virginica
# 125    125                   7.2  ...                  1.8  Iris-virginica
# 126    126                   6.2  ...                  1.8  Iris-virginica
# 127    127                   6.1  ...                  1.8  Iris-virginica
# 128    128                   6.4  ...                  2.1  Iris-virginica
# 129    129                   7.2  ...                  1.6  Iris-virginica
# 130    130                   7.4  ...                  1.9  Iris-virginica
# 131    131                   7.9  ...                  2.0  Iris-virginica
# 132    132                   6.4  ...                  2.2  Iris-virginica
# 133    133                   6.3  ...                  1.5  Iris-virginica
# 134    134                   6.1  ...                  1.4  Iris-virginica
# 135    135                   7.7  ...                  2.3  Iris-virginica
# 136    136                   6.3  ...                  2.4  Iris-virginica
# 137    137                   6.4  ...                  1.8  Iris-virginica
# 138    138                   6.0  ...                  1.8  Iris-virginica
# 139    139                   6.9  ...                  2.1  Iris-virginica
# 140    140                   6.7  ...                  2.4  Iris-virginica
# 141    141                   6.9  ...                  2.3  Iris-virginica
# 142    142                   5.8  ...                  1.9  Iris-virginica
# 143    143                   6.8  ...                  2.3  Iris-virginica
# 144    144                   6.7  ...                  2.5  Iris-virginica
# 145    145                   6.7  ...                  2.3  Iris-virginica
# 146    146                   6.3  ...                  1.9  Iris-virginica
# 147    147                   6.5  ...                  2.0  Iris-virginica
# 148    148                   6.2  ...                  2.3  Iris-virginica
# 149    149                   5.9  ...                  1.8  Iris-virginica
#
# [150 rows x 6 columns]

# %% [markdown]
# ### Take only the top 10 rows of the dataset with only first 3 columns and store it in a dataframe named "IrisSubset"

# %%
IrisSubset=iris1.iloc[0:10,0:3]

# %%
IrisSubset
# Out:
#    index  Sepal Length (in cm)  Sepal Width in (cm)
# 0      0                   5.1                  3.5
# 1      1                   4.9                  3.0
# 2      2                   4.7                  3.2
# 3      3                   4.6                  3.1
# 4      4                   5.0                  3.6
# 5      5                   5.4                  3.9
# 6      6                   4.6                  3.4
# 7      7                   5.0                  3.4
# 8      8                   4.4                  2.9
# 9      9                   4.9                  3.1

# %% [markdown]
# # Part-2

# %% [markdown]
# ## The dataset HR contains information collected from the survey floated by a HR within the company.
#
#
# As a part of this lab, you are expected to answer the below questions

# %% [markdown]
# ### Import numpy and Pandas

# %%
import numpy as np
import pandas as pd

# %% [markdown]
# ### Import the dataset (Note: The dataset is in .txt format) - Make sure to use delimiters

# %%
df=pd.read_csv('/content/drive/My Drive/Colab Notebooks/lab1606/HR_external.txt',sep='\t')
df.head()
# Out:
#   Individual  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 0        Ind1       Yes  ...                        0                     5
# 1        Ind2        No  ...                        1                     7
# 2        Ind3       Yes  ...                        0                     0
# 3        Ind4        No  ...                        3                     0
# 4        Ind5        No  ...                        2                     2
#
# [5 rows x 35 columns]

# %% [markdown]
# ### Print the no of rows and columns in the dataset

# %%
df.shape
# Out:
# (1470, 35)

# %% [markdown]
# ### Find out the type of each and every column in the dataset

# %%
df.dtypes
# Out:
# Individual                  object
# Attrition                   object
# Age                          int64
# BusinessTravel               int64
# DailyRate                    int64
# Department                   int64
# DistanceFromHome             int64
# Education                    int64
# EducationField               int64
# EmployeeCount                int64
# EmployeeNumber               int64
# EnvironmentSatisfaction      int64
# Gender                       int64
# HourlyRate                   int64
# JobInvolvement               int64
# JobLevel                     int64
# JobRole                      int64
# JobSatisfaction              int64
# MaritalStatus                int64
# MonthlyIncome                int64
# MonthlyRate                  int64
# NumCompaniesWorked           int64
# OverTime                     int64
# PercentSalaryHike            int64
# PerformanceRating            int64
# RelationshipSatisfaction     int64
# StandardHours                int64
# StockOptionLevel             int64
# TotalWorkingYears            int64
# TrainingTimesLastYear        int64
# WorkLifeBalance              int64
# YearsAtCompany               int64
# YearsInCurrentRole           int64
# YearsSinceLastPromotion      int64
# YearsWithCurrManager         int64
# dtype: object

# %% [markdown]
# ### Print out all the rows from 3rd column to 10th columns

# %%
df1=df.iloc[:,2:9]
df1
# Out:
#       Age  BusinessTravel  ...  Education  EducationField
# 0      41               1  ...          2               1
# 1      49               2  ...          1               1
# 2      37               1  ...          2               6
# 3      33               2  ...          4               1
# 4      27               1  ...          1               2
# 5      32               2  ...          2               1
# 6      59               1  ...          3               2
# 7      30               1  ...          1               1
# 8      38               2  ...          3               1
# 9      36               1  ...          3               2
# 10     35               1  ...          3               2
# 11     29               1  ...          2               1
# 12     31               1  ...          1               1
# 13     34               1  ...          2               2
# 14     28               1  ...          3               1
# 15     29               1  ...          4               1
# 16     32               1  ...          2               1
# 17     22               3  ...          2               2
# 18     53               1  ...          4               1
# 19     38               1  ...          3               1
# 20     24               3  ...          2               6
# 21     36               1  ...          4               1
# 22     34               1  ...          4               1
# 23     21               1  ...          2               1
# 24     34               1  ...          1               2
# 25     53               1  ...          3               6
# 26     32               2  ...          1               1
# 27     42               1  ...          4               3
# 28     44               1  ...          4               2
# 29     46               1  ...          4               3
# ...   ...             ...  ...        ...             ...
# 1440   36               2  ...          2               1
# 1441   56               3  ...          4               1
# 1442   29               1  ...          4               2
# 1443   42               1  ...          3               1
# 1444   56               1  ...          2               4
# 1445   41               1  ...          4               1
# 1446   34               1  ...          3               3
# 1447   36               3  ...          4               3
# 1448   41               1  ...          3               1
# 1449   32               1  ...          3               4
# 1450   35               1  ...          4               1
# 1451   38               1  ...          2               1
# 1452   50               2  ...          4               1
# 1453   36               1  ...          4               3
# 1454   45               1  ...          3               1
# 1455   40               1  ...          4               1
# 1456   35               2  ...          4               1
# 1457   40               1  ...          4               2
# 1458   35               1  ...          4               1
# 1459   29               1  ...          2               6
# 1460   29               1  ...          4               2
# 1461   50               1  ...          3               3
# 1462   39               1  ...          1               3
# 1463   31               3  ...          3               2
# 1464   26               1  ...          3               6
# 1465   36               2  ...          2               2
# 1466   39               1  ...          1               2
# 1467   27               1  ...          3               1
# 1468   49               2  ...          3               2
# 1469   34               1  ...          3               2
#
# [1470 rows x 7 columns]

# %% [markdown]
# ### Find out the no of male & female employees in the company
#
# *Hint: Use can use a condition to find out the no of 1s and 0s in gender and sum it*

# %%
df['Gender'].value_counts()
# Out:
# 1    882
# 2    588
# Name: Gender, dtype: int64

# %%
df
# Out:
#      Individual  Attrition  ...  YearsSinceLastPromotion  YearsWithCurrManager
# 0           Ind1       Yes  ...                        0                     5
# 1           Ind2        No  ...                        1                     7
# 2           Ind3       Yes  ...                        0                     0
# 3           Ind4        No  ...                        3                     0
# 4           Ind5        No  ...                        2                     2
# 5           Ind6        No  ...                        3                     6
# 6           Ind7        No  ...                        0                     0
# 7           Ind8        No  ...                        0                     0
# 8           Ind9        No  ...                        1                     8
# 9          Ind10        No  ...                        7                     7
# 10         Ind11        No  ...                        0                     3
# 11         Ind12        No  ...                        0                     8
# 12         Ind13        No  ...                        4                     3
# 13         Ind14        No  ...                        1                     2
# 14         Ind15       Yes  ...                        0                     3
# 15         Ind16        No  ...                        8                     8
# 16         Ind17        No  ...                        0                     5
# 17         Ind18        No  ...                        0                     0
# 18         Ind19        No  ...                        3                     7
# 19         Ind20        No  ...                        1                     2
# 20         Ind21        No  ...                        1                     3
# 21         Ind22       Yes  ...                        0                     3
# 22         Ind23        No  ...                        2                    11
# 23         Ind24        No  ...                        0                     0
# 24         Ind25       Yes  ...                        1                     3
# 25         Ind26        No  ...                        4                     8
# 26         Ind27       Yes  ...                        6                     7
# 27         Ind28        No  ...                        4                     2
# 28         Ind29        No  ...                        5                    17
# 29         Ind30        No  ...                        2                     1
# ...          ...       ...  ...                      ...                   ...
# 1440     Ind1441        No  ...                        0                     2
# 1441     Ind1442        No  ...                        1                     9
# 1442     Ind1443       Yes  ...                        2                     2
# 1443     Ind1444        No  ...                        4                    14
# 1444     Ind1445       Yes  ...                        9                     8
# 1445     Ind1446        No  ...                        0                    10
# 1446     Ind1447        No  ...                        1                     7
# 1447     Ind1448        No  ...                       11                    11
# 1448     Ind1449        No  ...                        0                     4
# 1449     Ind1450        No  ...                        1                     2
# 1450     Ind1451        No  ...                        1                     7
# 1451     Ind1452        No  ...                        1                     9
# 1452     Ind1453       Yes  ...                        0                     1
# 1453     Ind1454        No  ...                        0                     0
# 1454     Ind1455        No  ...                        0                     1
# 1455     Ind1456        No  ...                        2                     2
# 1456     Ind1457        No  ...                        0                     2
# 1457     Ind1458        No  ...                        0                     2
# 1458     Ind1459        No  ...                        1                     1
# 1459     Ind1460        No  ...                        0                     3
# 1460     Ind1461        No  ...                        0                     4
# 1461     Ind1462       Yes  ...                        2                     0
# 1462     Ind1463        No  ...                        9                     6
# 1463     Ind1464        No  ...                        1                     7
# 1464     Ind1465        No  ...                        0                     0
# 1465     Ind1466        No  ...                        0                     3
# 1466     Ind1467        No  ...                        1                     7
# 1467     Ind1468        No  ...                        0                     3
# 1468     Ind1469        No  ...                        0                     8
# 1469     Ind1470        No  ...                        1                     2
#
# [1470 rows x 35 columns]

# %% [markdown]
# ### Find out the IQR for the column - Age
#
# *Hint: IQR - Interquartile range = 75th percentile - 25th percentile*

# %%
df['Age'].quantile(0.75) - df['Age'].quantile(0.25)
# Out:
# 13.0

# %% [markdown]
# ### Find out the mean, median and variance for the column - DailyRate

# %%
df['DailyRate'].mean()
# Out:
# 802.4857142857143

# %%
df['DailyRate'].median()
# Out:
# 802.0

# %%
df['DailyRate'].var()
# Out:
# 162819.59373723628

# %% [markdown]
# ### Plot the attrition column (Since it is a categorical variable, chose the plot accordingly)

# %%
import matplotlib.pyplot as plt
import seaborn as sns
# %matplotlib inline

# %%
sns.countplot(x="Attrition", data=df)

# %% [markdown]
# ### Plot Total working years using matplotlib plot function

# %%
df['TotalWorkingYears'].hist(figsize=(10,10))
